# %% [markdown]
# # KLTN — V1.3: Regularize + Augment trên 56 đặc trưng hình học
#
# **Mục tiêu:** Cải thiện V1.2 (F1=0.7182) lên ≥ 0.78 (đạt ngưỡng tối thiểu đề cương) bằng:
#
# 1. **BiLSTM** thay LSTM thuần — bắt được pattern cả 2 chiều thời gian
# 2. **Dropout** 0.3/0.5 — chống overfit (V1.2 train_acc=0.90 nhưng val_acc=0.72 → overfit rõ ràng)
# 3. **Augmentation:** Gaussian noise σ=0.02 + Time crop ngẫu nhiên — tăng đa dạng dữ liệu
# 4. **Focal Loss** α=0.25, γ=2.0 — giảm dominant của mẫu dễ, ép mô hình học mẫu khó
# 5. **AdamW** + weight decay — chính quy hoá thêm
#
# **Dự kiến:** F1 0.75-0.82 (vượt ngưỡng 0.78 là thành công).
#
# ## Trước khi chạy
# - Folder `Human-Reco/processed_data1/` (56 feat) phải có sẵn trên Drive
# - Notebook V1.2 đã chạy xong (để so sánh)

# %% [markdown]
# ## 1. Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
ROOT_DIR = "/content/drive/MyDrive/KLTN_KTDL_Nhom28/Human-Reco"   # ★ Sửa nếu khác
assert os.path.exists(f"{ROOT_DIR}/processed_data1"), "Thiếu processed_data1/"
OUT_DIR = f"{ROOT_DIR}/training_outputs"
os.makedirs(OUT_DIR, exist_ok=True)
print(f"ROOT = {ROOT_DIR}")
# Out:
# ROOT = /content/drive/MyDrive/KLTN_KTDL_Nhom28/Human-Reco

# %%
# !pip install -q tensorflow scikit-learn pandas seaborn matplotlib numpy

# %%
import os, json, time, glob, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (LSTM, Bidirectional, Conv2D, MaxPooling2D,
                                     GlobalAveragePooling2D, BatchNormalization,
                                     Dense, Reshape, Input, Dropout, Lambda)
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import Sequence
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, f1_score
print("TF:", tf.__version__, "GPU:", tf.config.list_physical_devices('GPU'))
SEED = 42
np.random.seed(SEED); tf.random.set_seed(SEED)
# Out:
# TF: 2.20.0 GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Regenerate X 56-feat + clip_ids (như V1.2)

# %%
def regenerate_56feat(processed_root, seq_length=90, step=30):
    X, y, clip_ids = [], [], []
    for label_name in ['normal', 'shoplifting']:
        label_val = 0 if label_name == 'normal' else 1
        folder = os.path.join(processed_root, label_name)
        for fp in sorted(glob.glob(os.path.join(folder, "*.csv"))):
            clip_id = f"{label_name}/{os.path.basename(fp)}"
            data = pd.read_csv(fp).values
            if data.shape[1] != 56: continue
            for i in range(0, len(data) - seq_length + 1, step):
                X.append(data[i: i + seq_length])
                y.append(label_val)
                clip_ids.append(clip_id)
    return (np.array(X, dtype='float32'),
            np.array(y, dtype='int'),
            np.array(clip_ids))

X, y, clip_ids = regenerate_56feat(f"{ROOT_DIR}/processed_data1")
print(f"X.shape = {X.shape},  y.shape = {y.shape},  clips = {len(np.unique(clip_ids))}")
# Out:
# X.shape = (1336, 90, 56),  y.shape = (1336,),  clips = 155

# %% [markdown]
# ## 3. Split-by-clip (giống V1.1/V1.2)

# %%
gss1 = GroupShuffleSplit(n_splits=1, train_size=0.70, random_state=SEED)
idx_tr, idx_rem = next(gss1.split(X, y, groups=clip_ids))
gss2 = GroupShuffleSplit(n_splits=1, train_size=0.5, random_state=SEED+1)
idx_v_loc, idx_t_loc = next(gss2.split(X[idx_rem], y[idx_rem], groups=clip_ids[idx_rem]))
idx_v = idx_rem[idx_v_loc]; idx_t = idx_rem[idx_t_loc]
X_tr, y_tr = X[idx_tr], y[idx_tr]
X_v, y_v   = X[idx_v], y[idx_v]
X_t, y_t   = X[idx_t], y[idx_t]
assert not (set(clip_ids[idx_tr]) & set(clip_ids[idx_v]))
assert not (set(clip_ids[idx_tr]) & set(clip_ids[idx_t]))
assert not (set(clip_ids[idx_v])  & set(clip_ids[idx_t]))
print(f"Train: {len(idx_tr)} | Val: {len(idx_v)} | Test: {len(idx_t)}")
# Out:
# Train: 931 | Val: 192 | Test: 213

# %% [markdown]
# ## 4. Augmentation pipeline
#
# Áp dụng **chỉ trên tập train**. Hai phép tăng cường:
#
# - **Gaussian noise** σ=0.02 — mô phỏng nhiễu YOLO-Pose
# - **Time crop** random — cắt 60-90 frame liên tiếp rồi interpolate về 90, mô phỏng tốc độ hành động khác nhau
#
# Không dùng rotation/flip vì 56 đặc trưng hình học đã được tính trên cấu trúc cố định, biến đổi geometric phức tạp.

# %%
def augment_sample(sample, noise_std=0.02, crop_prob=0.3, training=True):
    """sample shape (90, 56). Áp dụng noise + time crop."""
    if not training:
        return sample
    s = sample.copy()
    # Gaussian noise
    if np.random.rand() < 0.8:
        s = s + np.random.normal(0, noise_std, s.shape).astype(np.float32)
    # Time crop
    if np.random.rand() < crop_prob:
        T = s.shape[0]
        crop_T = np.random.randint(60, T + 1)
        if crop_T < T:
            start = np.random.randint(0, T - crop_T + 1)
            cropped = s[start: start + crop_T]
            # Linear interpolate back to T
            idx_src = np.linspace(0, crop_T - 1, num=T)
            i_floor = np.floor(idx_src).astype(int)
            i_ceil = np.minimum(i_floor + 1, crop_T - 1)
            w = (idx_src - i_floor).astype(np.float32)[:, None]
            s = (1 - w) * cropped[i_floor] + w * cropped[i_ceil]
    return s.astype(np.float32)


class AugDataGen(Sequence):
    def __init__(self, X, y, batch_size=64, augment=True, shuffle=True):
        self.X = X; self.y = y
        self.bs = batch_size
        self.augment = augment
        self.shuffle = shuffle
        self.indices = np.arange(len(X))
        if shuffle:
            np.random.shuffle(self.indices)
    def __len__(self):
        return int(np.ceil(len(self.X) / self.bs))
    def __getitem__(self, idx):
        sl = self.indices[idx*self.bs : (idx+1)*self.bs]
        Xb = np.stack([augment_sample(self.X[i], training=self.augment) for i in sl])
        yb = self.y[sl]
        return Xb, yb
    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)


train_gen = AugDataGen(X_tr, y_tr, batch_size=64, augment=True,  shuffle=True)
val_gen   = AugDataGen(X_v,  y_v,  batch_size=64, augment=False, shuffle=False)
print(f"Train batches: {len(train_gen)}, Val batches: {len(val_gen)}")
# Test sample
xb, yb = train_gen[0]
print(f"Sample batch X shape: {xb.shape}, y shape: {yb.shape}, dtype: {xb.dtype}")
# Out:
# Train batches: 15, Val batches: 3
# Sample batch X shape: (64, 90, 56), y shape: (64,), dtype: float32

# %% [markdown]
# ## 5. Focal Loss

# %%
def focal_loss(alpha=0.25, gamma=2.0):
    """Focal loss cho sparse categorical (y_true là int 0/1)."""
    def loss_fn(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        y_true_oh = tf.one_hot(y_true, depth=tf.shape(y_pred)[-1])
        y_true_oh = tf.cast(y_true_oh, y_pred.dtype)
        y_pred_clamped = tf.clip_by_value(y_pred, 1e-8, 1.0 - 1e-8)
        ce = -y_true_oh * tf.math.log(y_pred_clamped)
        weight = alpha * tf.math.pow(1 - y_pred_clamped, gamma)
        focal = weight * ce
        return tf.reduce_mean(tf.reduce_sum(focal, axis=-1))
    return loss_fn

# %% [markdown]
# ## 6. Mô hình V1.3: BiLSTM + Dropout + Conv2D
#
# Thay đổi so V1.2:
# - LSTM → BiLSTM(32) (output 64 chiều thay vì 32)
# - Thêm Dropout(0.3) sau mỗi BiLSTM
# - Thêm Dropout(0.3) sau Conv2D
# - Thêm Dropout(0.5) trước Dense cuối
# - Reshape thành (90, 64, 1) vì BiLSTM ra 64 chiều

# %%
def build_v13(input_shape=(90, 56), num_classes=2):
    model = Sequential([
        Input(shape=input_shape),
        Bidirectional(LSTM(32, return_sequences=True)),
        Dropout(0.3),
        Bidirectional(LSTM(32, return_sequences=True)),
        Dropout(0.3),
        Reshape((90, 64, 1)),  # BiLSTM x2 trả về 64 features
        Conv2D(64, (5, 5), strides=(2, 2), padding='same', activation='relu'),
        MaxPooling2D((2, 2), strides=(2, 2)),
        Dropout(0.3),
        Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu'),
        GlobalAveragePooling2D(),
        BatchNormalization(),
        Dropout(0.5),
        Dense(num_classes, activation='softmax'),
    ])
    model.compile(
        optimizer=AdamW(learning_rate=1e-3, weight_decay=5e-4),
        loss=focal_loss(alpha=0.25, gamma=2.0),
        metrics=['accuracy'],
    )
    return model

model = build_v13()
model.summary()
print(f"\nTotal params: {model.count_params():,}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 90, 64)         │        22,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 90, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 90, 64)         │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 90, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 90, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 45, 32, 64)     │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 22, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 22, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 22, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 123,906 (484.01 KB)
#  Trainable params: 123,650 (483.01 KB)
#  Non-trainable params: 256 (1.00 KB)
# Total params: 123,906

# %% [markdown]
# ## 7. Train V1.3

# %%
ckpt_path = f"{OUT_DIR}/best_v1.3_56feat_regularized.keras"
cbs = [
    ModelCheckpoint(ckpt_path, monitor='val_loss', save_best_only=True, verbose=0),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-6, verbose=1),
]
t0 = time.time()
hist = model.fit(train_gen, validation_data=val_gen,
                 epochs=120, callbacks=cbs, verbose=2)
train_time = time.time() - t0
print(f"\nTrained {len(hist.history['loss'])} epochs in {train_time:.1f}s")
# Out:
# Epoch 1/120
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 15/15 - 19s - 1s/step - accuracy: 0.6337 - loss: 0.0401 - val_accuracy: 0.5729 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 2/120
# 15/15 - 1s - 42ms/step - accuracy: 0.7358 - loss: 0.0335 - val_accuracy: 0.5729 - val_loss: 0.0424 - learning_rate: 0.0010
# Epoch 3/120
# 15/15 - 1s - 36ms/step - accuracy: 0.7637 - loss: 0.0321 - val_accuracy: 0.6146 - val_loss: 0.0430 - learning_rate: 0.0010
# Epoch 4/120
# 15/15 - 1s - 41ms/step - accuracy: 0.7755 - loss: 0.0298 - val_accuracy: 0.4948 - val_loss: 0.0431 - learning_rate: 0.0010
# Epoch 5/120
# 15/15 - 1s - 35ms/step - accuracy: 0.8013 - loss: 0.0262 - val_accuracy: 0.4844 - val_loss: 0.0432 - learning_rate: 0.0010
# Epoch 6/120
# 15/15 - 1s - 43ms/step - accuracy: 0.8281 - loss: 0.0274 - val_accuracy: 0.5625 - val_loss: 0.0412 - learning_rate: 0.0010
# Epoch 7/120
# 15/15 - 1s - 34ms/step - accuracy: 0.8400 - loss: 0.0254 - val_accuracy: 0.5729 - val_loss: 0.0423 - learning_rate: 0.0010
# Epoch 8/120
# 15/15 - 1s - 43ms/step - accuracy: 0.8453 - loss: 0.0246 - val_accuracy: 0.7240 - val_loss: 0.0408 - learning_rate: 0.0010
# Epoch 9/120
# 15/15 - 1s - 42ms/step - accuracy: 0.8722 - loss: 0.0221 - val_accuracy: 0.7344 - val_loss: 0.0400 - learning_rate: 0.0010
# Epoch 10/120
# 15/15 - 1s - 36ms/step - accuracy: 0.8797 - loss: 0.0200 - val_accuracy: 0.7344 - val_loss: 0.0401 - learning_rate: 0.0010
# Epoch 11/120
# 15/15 - 1s - 42ms/step - accuracy: 0.8797 - loss: 0.0206 - val_accuracy: 0.7344 - val_loss: 0.0397 - learning_rate: 0.0010
# Epoch 12/120
# 15/15 - 1s - 41ms/step - accuracy: 0.8894 - loss: 0.0186 - val_accuracy: 0.7448 - val_loss: 0.0391 - learning_rate: 0.0010
# Epoch 13/120
# 15/15 - 1s - 37ms/step - accuracy: 0.8786 - loss: 0.0204 - val_accuracy: 0.6250 - val_loss: 0.0406 - learning_rate: 0.0010
# Epoch 14/120
# 15/15 - 1s - 34ms/step - accuracy: 0.8582 - loss: 0.0219 - val_accuracy: 0.7396 - val_loss: 0.0400 - learning_rate: 0.0010
# Epoch 15/120
# 15/15 - 1s - 52ms/step - accuracy: 0.8872 - loss: 0.0181 - val_accuracy: 0.7344 - val_loss: 0.0375 - learning_rate: 0.0010
# Epoch 16/120
# 15/15 - 1s - 35ms/step - accuracy: 0.8958 - loss: 0.0167 - val_accuracy: 0.7396 - val_loss: 0.0383 - learning_rate: 0.0010
# Epoch 17/120
# 15/15 - 1s - 43ms/step - accuracy: 0.9162 - loss: 0.0145 - val_accuracy: 0.7552 - val_loss: 0.0361 - learning_rate: 0.0010
# Epoch 18/120
# 15/15 - 1s - 47ms/step - accuracy: 0.9108 - loss: 0.0145 - val_accuracy: 0.6562 - val_loss: 0.0370 - learning_rate: 0.0010
# Epoch 19/120
# 15/15 - 1s - 60ms/step - accuracy: 0.9033 - loss: 0.0176 - val_accuracy: 0.7031 - val_loss: 0.0388 - learning_rate: 0.0010
# Epoch 20/120
# 15/15 - 1s - 82ms/step - accuracy: 0.9066 - loss: 0.0159 - val_accuracy: 0.7031 - val_loss: 0.0364 - learning_rate: 0.0010
# Epoch 21/120
# 15/15 - 1s - 79ms/step - accuracy: 0.9130 - loss: 0.0141 - val_accuracy: 0.6979 - val_loss: 0.0381 - learning_rate: 0.0010
# Epoch 22/120
# 15/15 - 1s - 36ms/step - accuracy: 0.9141 - loss: 0.0148 - val_accuracy: 0.5885 - val_loss: 0.0381 - learning_rate: 0.0010
# Epoch 23/120
# 15/15 - 1s - 36ms/step - accuracy: 0.9076 - loss: 0.0147 - val_accuracy: 0.6198 - val_loss: 0.0366 - learning_rate: 0.0010
# Epoch 24/120
# 15/15 - 1s - 42ms/step - accuracy: 0.9023 - loss: 0.0155 - val_accuracy: 0.7240 - val_loss: 0.0352 - learning_rate: 0.0010
# Epoch 25/120
# 15/15 - 1s - 42ms/step - accuracy: 0.9012 - loss: 0.0147 - val_accuracy: 0.7500 - val_loss: 0.0333 - learning_rate: 0.0010
# Epoch 26/120
# 15/15 - 1s - 36ms/step - accuracy: 0.9055 - loss: 0.0153 - val_accuracy: 0.7448 - val_loss: 0.0353 - learning_rate: 0.0010
# Epoch 27/120
# 15/15 - 1s - 47ms/step - accuracy: 0.9227 - loss: 0.0137 - val_accuracy: 0.7760 - val_loss: 0.0321 - learning_rate: 0.0010
# Epoch 28/120
# 15/15 - 1s - 36ms/step - accuracy: 0.9173 - loss: 0.0133 - val_accuracy: 0.7396 - val_loss: 0.0329 - learning_rate: 0.0010
# Epoch 29/120
# 15/15 - 1s - 35ms/step - accuracy: 0.9205 - loss: 0.0138 - val_accuracy: 0.6458 - val_loss: 0.0340 - learning_rate: 0.0010
# Epoch 30/120
# 15/15 - 1s - 37ms/step - accuracy: 0.9259 - loss: 0.0126 - val_accuracy: 0.7552 - val_loss: 0.0341 - learning_rate: 0.0010
# Epoch 31/120
# 15/15 - 1s - 40ms/step - accuracy: 0.9313 - loss: 0.0104 - val_accuracy: 0.7188 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 32/120
# 15/15 - 1s - 37ms/step - accuracy: 0.9323 - loss: 0.0111 - val_accuracy: 0.6667 - val_loss: 0.0468 - learning_rate: 0.0010
# Epoch 33/120
# 15/15 - 1s - 43ms/step - accuracy: 0.9141 - loss: 0.0133 - val_accuracy: 0.7292 - val_loss: 0.0294 - learning_rate: 0.0010
# Epoch 34/120
# 15/15 - 1s - 43ms/step - accuracy: 0.9302 - loss: 0.0116 - val_accuracy: 0.7240 - val_loss: 0.0292 - learning_rate: 0.0010
# Epoch 35/120
# 15/15 - 1s - 37ms/step - accuracy: 0.9474 - loss: 0.0104 - val_accuracy: 0.7500 - val_loss: 0.0371 - learning_rate: 0.0010
# Epoch 36/120
# 15/15 - 1s - 35ms/step - accuracy: 0.9388 - loss: 0.0103 - val_accuracy: 0.7708 - val_loss: 0.0356 - learning_rate: 0.0010
# Epoch 37/120
# 15/15 - 1s - 37ms/step - accuracy: 0.9334 - loss: 0.0120 - val_accuracy: 0.7865 - val_loss: 0.0414 - learning_rate: 0.0010
# Epoch 38/120
# 15/15 - 1s - 36ms/step - accuracy: 0.9248 - loss: 0.0122 - val_accuracy: 0.7344 - val_loss: 0.0412 - learning_rate: 0.0010
# Epoch 39/120
# 15/15 - 1s - 55ms/step - accuracy: 0.9248 - loss: 0.0114 - val_accuracy: 0.6823 - val_loss: 0.0375 - learning_rate: 0.0010
# Epoch 40/120
# 15/15 - 1s - 55ms/step - accuracy: 0.9237 - loss: 0.0119 - val_accuracy: 0.6875 - val_loss: 0.0713 - learning_rate: 0.0010
# Epoch 41/120
# 15/15 - 1s - 57ms/step - accuracy: 0.9377 - loss: 0.0100 - val_accuracy: 0.7552 - val_loss: 0.0595 - learning_rate: 0.0010
# Epoch 42/120
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 15/15 - 1s - 53ms/step - accuracy: 0.9474 - loss: 0.0092 - val_accuracy: 0.7448 - val_loss: 0.0412 - learning_rate: 0.0010
# Epoch 43/120
# 15/15 - 1s - 53ms/step - accuracy: 0.9538 - loss: 0.0087 - val_accuracy: 0.7812 - val_loss: 0.0463 - learning_rate: 5.0000e-04
# Epoch 44/120
# 15/15 - 1s - 38ms/step - accuracy: 0.9570 - loss: 0.0080 - val_accuracy: 0.7656 - val_loss: 0.0442 - learning_rate: 5.0000e-04
# Epoch 45/120
# 15/15 - 1s - 36ms/step - accuracy: 0.9463 - loss: 0.0097 - val_accuracy: 0.7604 - val_loss: 0.0561 - learning_rate: 5.0000e-04
# Epoch 46/120
# 15/15 - 1s - 37ms/step - accuracy: 0.9581 - loss: 0.0065 - val_accuracy: 0.7604 - val_loss: 0.0667 - learning_rate: 5.0000e-04
# Epoch 47/120
# 15/15 - 1s - 37ms/step - accuracy: 0.9570 - loss: 0.0082 - val_accuracy: 0.7760 - val_loss: 0.0590 - learning_rate: 5.0000e-04
# Epoch 48/120
# 15/15 - 1s - 37ms/step - accuracy: 0.9581 - loss: 0.0072 - val_accuracy: 0.7656 - val_loss: 0.0572 - learning_rate: 5.0000e-04
# Epoch 49/120
# 15/15 - 1s - 35ms/step - accuracy: 0.9484 - loss: 0.0075 - val_accuracy: 0.7083 - val_loss: 0.0660 - learning_rate: 5.0000e-04
# Epoch 50/120
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 15/15 - 1s - 43ms/step - accuracy: 0.9549 - loss: 0.0083 - val_accuracy: 0.7812 - val_loss: 0.0648 - learning_rate: 5.0000e-04
# Epoch 51/120
# 15/15 - 1s - 36ms/step - accuracy: 0.9603 - loss: 0.0076 - val_accuracy: 0.7656 - val_loss: 0.0538 - learning_rate: 2.5000e-04
# Epoch 52/120
# 15/15 - 1s - 42ms/step - accuracy: 0.9613 - loss: 0.0067 - val_accuracy: 0.7760 - val_loss: 0.0647 - learning_rate: 2.5000e-04
# Epoch 53/120
# 15/15 - 1s - 36ms/step - accuracy: 0.9678 - loss: 0.0054 - val_accuracy: 0.7656 - val_loss: 0.0821 - learning_rate: 2.5000e-04
# Epoch 54/120
# 15/15 - 1s - 34ms/step - accuracy: 0.9689 - loss: 0.0047 - val_accuracy: 0.7552 - val_loss: 0.0799 - learning_rate: 2.5000e-04
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 34.
#
# Trained 54 epochs in 52.5s

# %% [markdown]
# ## 8. Đánh giá trên test set

# %%
# Không augment khi predict
y_pred = model.predict(X_t, verbose=0).argmax(1)
f1m = f1_score(y_t, y_pred, average='macro')
report = classification_report(y_t, y_pred, target_names=['Normal','Shoplifting'], digits=4)
cm = confusion_matrix(y_t, y_pred)
print(report)
print(f"Confusion matrix:\n{cm}")
print(f"F1-macro: {f1m:.4f}")

log = {
    "config": "v1.3_56feat_regularized",
    "input_shape": [90, 56],
    "improvements": [
        "BiLSTM thay LSTM",
        "Dropout 0.3/0.3/0.3/0.5",
        "Gaussian noise σ=0.02 + Time crop augmentation",
        "Focal Loss α=0.25 γ=2.0",
        "AdamW + weight_decay 5e-4",
    ],
    "train_size": int(X_tr.shape[0]),
    "val_size": int(X_v.shape[0]),
    "test_size": int(X_t.shape[0]),
    "epochs_trained": len(hist.history['loss']),
    "best_val_loss": float(min(hist.history['val_loss'])),
    "test_f1_macro": float(f1m),
    "test_confusion_matrix": cm.tolist(),
    "test_classification_report": report,
    "train_time_sec": train_time,
    "total_params": int(model.count_params()),
    "history": {k: [float(v) for v in vs] for k, vs in hist.history.items()},
}
with open(f"{OUT_DIR}/log_v1.3_56feat_regularized.json", "w") as f:
    json.dump(log, f, indent=2, ensure_ascii=False)
print(f"\n✓ Saved {OUT_DIR}/log_v1.3_56feat_regularized.json")
# Out:
#               precision    recall  f1-score   support
#
#       Normal     0.8482    0.7851    0.8155       121
#  Shoplifting     0.7426    0.8152    0.7772        92
#
#     accuracy                         0.7981       213
#    macro avg     0.7954    0.8002    0.7963       213
# weighted avg     0.8026    0.7981    0.7989       213
#
# Confusion matrix:
# [[95 26]
#  [17 75]]
# F1-macro: 0.7963
#
# ✓ Saved /content/drive/MyDrive/KLTN_KTDL_Nhom28/Human-Reco/training_outputs/log_v1.3_56feat_regularized.json

# %% [markdown]
# ## 9. So sánh V1.1 → V1.2 → V1.3

# %%
results = {"V1.3 — Regularized": f1m}
for name, fn in [("V1.1 — 34 feat", "log_v1.1_split_by_clip.json"),
                 ("V1.2 — 56 feat", "log_v1.2_56feat_by_clip.json")]:
    try:
        with open(f"{OUT_DIR}/{fn}") as f:
            results[name] = json.load(f)["test_f1_macro"]
    except FileNotFoundError:
        pass

print("So sánh trên cùng test set (split-by-clip):")
for k, v in sorted(results.items()):
    print(f"  {k:<22}: F1 = {v:.4f}")
print()
if "V1.1 — 34 feat" in results:
    print(f"  V1.2 vs V1.1: {results.get('V1.2 — 56 feat', 0) - results['V1.1 — 34 feat']:+.4f}")
if "V1.2 — 56 feat" in results:
    print(f"  V1.3 vs V1.2: {f1m - results['V1.2 — 56 feat']:+.4f}")

# Đạt ngưỡng đề cương chưa?
print()
if f1m >= 0.80:
    print("🎉 ĐẠT ngưỡng xuất sắc (≥ 0.80)! Tiếp tục V2.0 ST-GCN để có đóng góp học thuật.")
elif f1m >= 0.78:
    print("✓ ĐẠT ngưỡng tối thiểu (≥ 0.78)! Đã đáp ứng đề cương. V2.0 vẫn nên làm để vượt 0.85.")
elif f1m >= 0.72:
    print("~ Cải thiện tốt nhưng chưa đạt 0.78. Có thể train thêm hoặc nhảy V2.0 ST-GCN.")
else:
    print("✗ Cải thiện ít. Vấn đề có thể ở dataset/kiến trúc, chuyển V2.0 ST-GCN.")
# Out:
# So sánh trên cùng test set (split-by-clip):
#   V1.1 — 34 feat        : F1 = 0.5526
#   V1.2 — 56 feat        : F1 = 0.7182
#   V1.3 — Regularized    : F1 = 0.7963
#
#   V1.2 vs V1.1: +0.1656
#   V1.3 vs V1.2: +0.0782
#
# ✓ ĐẠT ngưỡng tối thiểu (≥ 0.78)! Đã đáp ứng đề cương. V2.0 vẫn nên làm để vượt 0.85.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Plot 1: training curves
axes[0].plot(hist.history['accuracy'], label='train', alpha=0.8)
axes[0].plot(hist.history['val_accuracy'], label='val', alpha=0.8)
axes[0].set_title('V1.3 — Accuracy'); axes[0].set_xlabel('Epoch')
axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(hist.history['loss'], label='train', alpha=0.8)
axes[1].plot(hist.history['val_loss'], label='val', alpha=0.8)
axes[1].set_title('V1.3 — Loss'); axes[1].set_xlabel('Epoch')
axes[1].legend(); axes[1].grid(alpha=0.3)

# Plot 3: confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[2],
            xticklabels=['Normal','Shoplifting'], yticklabels=['Normal','Shoplifting'])
axes[2].set_title(f'V1.3 — Confusion Matrix\\nF1={f1m:.4f}')
axes[2].set_xlabel('Dự đoán'); axes[2].set_ylabel('Thực tế')

plt.tight_layout()
plt.savefig(f"{OUT_DIR}/v1.3_summary.png", dpi=150, bbox_inches='tight')
plt.show()
print(f"✓ Saved {OUT_DIR}/v1.3_summary.png")
# Out:
# ✓ Saved /content/drive/MyDrive/KLTN_KTDL_Nhom28/Human-Reco/training_outputs/v1.3_summary.png

# %% [markdown]
# ## 10. Bước tiếp theo
#
# Gửi cho tôi `log_v1.3_56feat_regularized.json` để cập nhật báo cáo:
# - **Bảng 3.2 mở rộng**: thêm dòng V1.3 (kèm Δ với V1.2)
# - **Phân tích 3.5.1**: thảo luận tác động của Dropout/BiLSTM/Augment/Focal
# - **Curve accuracy/loss** sẽ chèn vào báo cáo (Hình 3.x)
#
# Quyết định bước kế tiếp dựa kết quả V1.3:
#
# | F1 V1.3 | Hành động |
# |---|---|
# | ≥ 0,80 | Đã vượt ngưỡng tối thiểu. Tiếp V2.0 ST-GCN cho đóng góp học thuật. |
# | 0,75 – 0,79 | Gần ngưỡng. Có thể V2.0 ST-GCN hoặc V1.4 (thêm confidence channel). |
# | 0,72 – 0,74 | Plateau với Keras 56-feat. Chuyển V2.0 (PyTorch + ST-GCN). |
# | < 0,72 | Quá thấp — có thể train hỏng (kiểm tra log). |
