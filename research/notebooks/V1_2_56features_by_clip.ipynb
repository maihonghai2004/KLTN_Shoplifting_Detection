# %% [markdown]
# # KLTN — V1.2: Train với 56 đặc trưng hình học + Split-by-Clip
#
# **Mục tiêu:** Cải thiện V1.1 (F1=0.5526) bằng cách dùng `processed_data1/` (56 geometric features) của Hảo thay vì 34 toạ độ thô.
#
# **Lý do:** Theo bài báo Hảo cite, các đặc trưng hình học (relative keypoint + bone vector + hand-hip distance) mã hoá cấu trúc cơ thể tốt hơn toạ độ thô và mô hình có khả năng học hành vi tay đưa vào túi.
#
# **Dự kiến:** F1 V1.2 ≈ 0.65-0.75 (nếu geometric features có giá trị) hoặc vẫn ≈ 0.55 (nếu vấn đề là kiến trúc hoặc dataset).
#
# ## Trước khi chạy
# 1. Folder `Human-Reco/processed_data1/` phải có trên Drive (76 file `normal/` + 79 file `shoplifting/`).
# 2. Notebook này KHÔNG dùng `X_data.npy` (vì là 34 feat). Sẽ regenerate từ CSV.
# 3. Vẫn dùng `clip_ids` để split — đảm bảo so sánh fair với V1.1.

# %% [markdown]
# ## 1. Mount Drive + cấu hình

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
ROOT_DIR = "/content/drive/MyDrive/KLTN_KTDL_Nhom28/Human-Reco"  # ★ Sửa nếu khác
assert os.path.exists(f"{ROOT_DIR}/processed_data1"), "Thiếu processed_data1/"
OUT_DIR = f"{ROOT_DIR}/training_outputs"
os.makedirs(OUT_DIR, exist_ok=True)
print(f"ROOT_DIR = {ROOT_DIR}")
# Out:
# ROOT_DIR = /content/drive/MyDrive/KLTN_KTDL_Nhom28/Human-Reco

# %% [markdown]
# ## 2. Cài deps + import

# %%
# !pip install -q tensorflow scikit-learn pandas seaborn matplotlib numpy

# %%
import os, json, time, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (LSTM, Conv2D, MaxPooling2D, GlobalAveragePooling2D,
                                     BatchNormalization, Dense, Reshape, Input, Dropout, Bidirectional)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, f1_score
print("TF:", tf.__version__, "GPU:", tf.config.list_physical_devices('GPU'))
SEED = 42
np.random.seed(SEED); tf.random.set_seed(SEED)
# Out:
# TF: 2.20.0 GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 3. Regenerate X 56-feat + clip_ids từ `processed_data1/`
#
# Replay đúng logic `prepare_data(1).py` của Hảo với `seq_length=90, step=30`.

# %%
def regenerate_56feat(processed_root, seq_length=90, step=30):
    X, y, clip_ids = [], [], []
    for label_name in ['normal', 'shoplifting']:
        label_val = 0 if label_name == 'normal' else 1
        folder = os.path.join(processed_root, label_name)
        files = sorted(glob.glob(os.path.join(folder, "*.csv")))
        for fp in files:
            clip_id = f"{label_name}/{os.path.basename(fp)}"
            data = pd.read_csv(fp).values
            if data.shape[1] != 56:
                print(f"⚠ {fp} có {data.shape[1]} cột, bỏ qua")
                continue
            for i in range(0, len(data) - seq_length + 1, step):
                X.append(data[i : i + seq_length])
                y.append(label_val)
                clip_ids.append(clip_id)
    return (np.array(X, dtype='float32'),
            np.array(y, dtype='int'),
            np.array(clip_ids))

X, y, clip_ids = regenerate_56feat(f"{ROOT_DIR}/processed_data1")
print(f"X.shape = {X.shape}")
print(f"y.shape = {y.shape}")
print(f"Số clip: {len(np.unique(clip_ids))}")
u, c = np.unique(y, return_counts=True)
for ui, ci in zip(u, c):
    print(f"  class {ui}: {ci} ({100*ci/len(y):.1f}%)")
print(f"X min/max: {X.min():.4f} / {X.max():.4f}")
print(f"X mean/std: {X.mean():.4f} / {X.std():.4f}")
# Out:
# X.shape = (1336, 90, 56)
# y.shape = (1336,)
# Số clip: 155
#   class 0: 667 (49.9%)
#   class 1: 669 (50.1%)
# X min/max: -0.5976 / 0.4082
# X mean/std: 0.0010 / 0.1361

# %% [markdown]
# ## 4. Build mô hình LSTM-CNN (input shape (90, 56) thay vì (90, 34))

# %%
def build_hybrid_model_56(input_shape=(90, 56), num_classes=2):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(32, return_sequences=True),
        LSTM(32, return_sequences=True),
        Reshape((90, 32, 1)),
        Conv2D(64, kernel_size=(5, 5), strides=(2, 2), padding='same', activation='relu'),
        MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
        Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'),
        GlobalAveragePooling2D(),
        BatchNormalization(),
        Dense(num_classes, activation='softmax'),
    ])
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

build_hybrid_model_56().summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 90, 32)         │        11,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 90, 32)         │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 90, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 45, 16, 64)     │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 22, 8, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 22, 8, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 96,002 (375.01 KB)
#  Trainable params: 95,746 (374.01 KB)
#  Non-trainable params: 256 (1.00 KB)

# %% [markdown]
# ## 5. Split-by-clip 70/15/15 (giống V1.1)

# %%
gss1 = GroupShuffleSplit(n_splits=1, train_size=0.70, random_state=SEED)
idx_tr, idx_rem = next(gss1.split(X, y, groups=clip_ids))
gss2 = GroupShuffleSplit(n_splits=1, train_size=0.5, random_state=SEED+1)
idx_v_loc, idx_t_loc = next(gss2.split(X[idx_rem], y[idx_rem], groups=clip_ids[idx_rem]))
idx_v = idx_rem[idx_v_loc]; idx_t = idx_rem[idx_t_loc]

X_tr, y_tr = X[idx_tr], y[idx_tr]
X_v, y_v = X[idx_v], y[idx_v]
X_t, y_t = X[idx_t], y[idx_t]

# Assert không leak
clips_tr, clips_v, clips_t = set(clip_ids[idx_tr]), set(clip_ids[idx_v]), set(clip_ids[idx_t])
assert not (clips_tr & clips_v), "LEAK train↔val"
assert not (clips_tr & clips_t), "LEAK train↔test"
assert not (clips_v & clips_t),  "LEAK val↔test"
print(f"Train: {len(idx_tr)} mẫu / {len(clips_tr)} clip")
print(f"Val:   {len(idx_v)} mẫu / {len(clips_v)} clip")
print(f"Test:  {len(idx_t)} mẫu / {len(clips_t)} clip")
# Out:
# Train: 931 mẫu / 108 clip
# Val:   192 mẫu / 23 clip
# Test:  213 mẫu / 24 clip

# %% [markdown]
# ## 6. Train V1.2

# %%
model = build_hybrid_model_56()
ckpt_path = f"{OUT_DIR}/best_v1.2_56feat_by_clip.keras"
cbs = [
    ModelCheckpoint(ckpt_path, monitor='val_loss', save_best_only=True),
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1),
]
t0 = time.time()
hist = model.fit(X_tr, y_tr, validation_data=(X_v, y_v),
                 epochs=100, batch_size=64, callbacks=cbs, verbose=2)
train_time = time.time() - t0
print(f"\nTraining time: {train_time:.1f}s, epochs trained: {len(hist.history['loss'])}")
# Out:
# Epoch 1/100
# 15/15 - 9s - 630ms/step - accuracy: 0.6079 - loss: 0.6786 - val_accuracy: 0.5729 - val_loss: 0.6900 - learning_rate: 1.0000e-04
# Epoch 2/100
# 15/15 - 0s - 24ms/step - accuracy: 0.6788 - loss: 0.6463 - val_accuracy: 0.5729 - val_loss: 0.6867 - learning_rate: 1.0000e-04
# Epoch 3/100
# 15/15 - 0s - 24ms/step - accuracy: 0.6907 - loss: 0.6104 - val_accuracy: 0.5729 - val_loss: 0.6830 - learning_rate: 1.0000e-04
# Epoch 4/100
# 15/15 - 0s - 25ms/step - accuracy: 0.7046 - loss: 0.5745 - val_accuracy: 0.5729 - val_loss: 0.6795 - learning_rate: 1.0000e-04
# Epoch 5/100
# 15/15 - 1s - 40ms/step - accuracy: 0.7164 - loss: 0.5503 - val_accuracy: 0.5729 - val_loss: 0.6770 - learning_rate: 1.0000e-04
# Epoch 6/100
# 15/15 - 0s - 24ms/step - accuracy: 0.7261 - loss: 0.5335 - val_accuracy: 0.5729 - val_loss: 0.6753 - learning_rate: 1.0000e-04
# Epoch 7/100
# 15/15 - 0s - 28ms/step - accuracy: 0.7390 - loss: 0.5199 - val_accuracy: 0.5729 - val_loss: 0.6733 - learning_rate: 1.0000e-04
# Epoch 8/100
# 15/15 - 1s - 35ms/step - accuracy: 0.7476 - loss: 0.5083 - val_accuracy: 0.5729 - val_loss: 0.6710 - learning_rate: 1.0000e-04
# Epoch 9/100
# 15/15 - 0s - 33ms/step - accuracy: 0.7562 - loss: 0.4972 - val_accuracy: 0.5729 - val_loss: 0.6683 - learning_rate: 1.0000e-04
# Epoch 10/100
# 15/15 - 1s - 46ms/step - accuracy: 0.7669 - loss: 0.4865 - val_accuracy: 0.5729 - val_loss: 0.6653 - learning_rate: 1.0000e-04
# Epoch 11/100
# 15/15 - 0s - 33ms/step - accuracy: 0.7723 - loss: 0.4760 - val_accuracy: 0.5729 - val_loss: 0.6621 - learning_rate: 1.0000e-04
# Epoch 12/100
# 15/15 - 1s - 36ms/step - accuracy: 0.7809 - loss: 0.4658 - val_accuracy: 0.5729 - val_loss: 0.6586 - learning_rate: 1.0000e-04
# Epoch 13/100
# 15/15 - 1s - 36ms/step - accuracy: 0.7884 - loss: 0.4559 - val_accuracy: 0.5729 - val_loss: 0.6546 - learning_rate: 1.0000e-04
# Epoch 14/100
# 15/15 - 0s - 30ms/step - accuracy: 0.7959 - loss: 0.4462 - val_accuracy: 0.5729 - val_loss: 0.6504 - learning_rate: 1.0000e-04
# Epoch 15/100
# 15/15 - 0s - 25ms/step - accuracy: 0.8088 - loss: 0.4367 - val_accuracy: 0.5729 - val_loss: 0.6458 - learning_rate: 1.0000e-04
# Epoch 16/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8110 - loss: 0.4278 - val_accuracy: 0.5729 - val_loss: 0.6410 - learning_rate: 1.0000e-04
# Epoch 17/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8185 - loss: 0.4192 - val_accuracy: 0.5729 - val_loss: 0.6360 - learning_rate: 1.0000e-04
# Epoch 18/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8249 - loss: 0.4111 - val_accuracy: 0.5729 - val_loss: 0.6307 - learning_rate: 1.0000e-04
# Epoch 19/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8228 - loss: 0.4033 - val_accuracy: 0.5781 - val_loss: 0.6256 - learning_rate: 1.0000e-04
# Epoch 20/100
# 15/15 - 0s - 25ms/step - accuracy: 0.8281 - loss: 0.3960 - val_accuracy: 0.5833 - val_loss: 0.6202 - learning_rate: 1.0000e-04
# Epoch 21/100
# 15/15 - 0s - 25ms/step - accuracy: 0.8357 - loss: 0.3889 - val_accuracy: 0.5833 - val_loss: 0.6150 - learning_rate: 1.0000e-04
# Epoch 22/100
# 15/15 - 0s - 23ms/step - accuracy: 0.8410 - loss: 0.3821 - val_accuracy: 0.5833 - val_loss: 0.6101 - learning_rate: 1.0000e-04
# Epoch 23/100
# 15/15 - 0s - 26ms/step - accuracy: 0.8453 - loss: 0.3755 - val_accuracy: 0.5833 - val_loss: 0.6060 - learning_rate: 1.0000e-04
# Epoch 24/100
# 15/15 - 0s - 23ms/step - accuracy: 0.8485 - loss: 0.3691 - val_accuracy: 0.5833 - val_loss: 0.6019 - learning_rate: 1.0000e-04
# Epoch 25/100
# 15/15 - 0s - 25ms/step - accuracy: 0.8539 - loss: 0.3629 - val_accuracy: 0.5833 - val_loss: 0.5983 - learning_rate: 1.0000e-04
# Epoch 26/100
# 15/15 - 0s - 23ms/step - accuracy: 0.8571 - loss: 0.3568 - val_accuracy: 0.5938 - val_loss: 0.5955 - learning_rate: 1.0000e-04
# Epoch 27/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8614 - loss: 0.3508 - val_accuracy: 0.5990 - val_loss: 0.5943 - learning_rate: 1.0000e-04
# Epoch 28/100
# 15/15 - 0s - 23ms/step - accuracy: 0.8625 - loss: 0.3449 - val_accuracy: 0.5990 - val_loss: 0.5927 - learning_rate: 1.0000e-04
# Epoch 29/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8690 - loss: 0.3393 - val_accuracy: 0.5990 - val_loss: 0.5918 - learning_rate: 1.0000e-04
# Epoch 30/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8722 - loss: 0.3339 - val_accuracy: 0.5990 - val_loss: 0.5910 - learning_rate: 1.0000e-04
# Epoch 31/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8733 - loss: 0.3288 - val_accuracy: 0.6094 - val_loss: 0.5903 - learning_rate: 1.0000e-04
# Epoch 32/100
# 15/15 - 0s - 25ms/step - accuracy: 0.8754 - loss: 0.3240 - val_accuracy: 0.6406 - val_loss: 0.5894 - learning_rate: 1.0000e-04
# Epoch 33/100
# 15/15 - 0s - 23ms/step - accuracy: 0.8818 - loss: 0.3196 - val_accuracy: 0.6510 - val_loss: 0.5891 - learning_rate: 1.0000e-04
# Epoch 34/100
# 15/15 - 0s - 20ms/step - accuracy: 0.8797 - loss: 0.3154 - val_accuracy: 0.6562 - val_loss: 0.5902 - learning_rate: 1.0000e-04
# Epoch 35/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8776 - loss: 0.3114 - val_accuracy: 0.6615 - val_loss: 0.5923 - learning_rate: 1.0000e-04
# Epoch 36/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8776 - loss: 0.3077 - val_accuracy: 0.6667 - val_loss: 0.5969 - learning_rate: 1.0000e-04
# Epoch 37/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8818 - loss: 0.3044 - val_accuracy: 0.6667 - val_loss: 0.6013 - learning_rate: 1.0000e-04
# Epoch 38/100
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 15/15 - 0s - 20ms/step - accuracy: 0.8861 - loss: 0.3014 - val_accuracy: 0.6719 - val_loss: 0.6050 - learning_rate: 1.0000e-04
# Epoch 39/100
# 15/15 - 0s - 23ms/step - accuracy: 0.8851 - loss: 0.2950 - val_accuracy: 0.7188 - val_loss: 0.5714 - learning_rate: 5.0000e-05
# Epoch 40/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8894 - loss: 0.2918 - val_accuracy: 0.7083 - val_loss: 0.5920 - learning_rate: 5.0000e-05
# Epoch 41/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8894 - loss: 0.2904 - val_accuracy: 0.7188 - val_loss: 0.5837 - learning_rate: 5.0000e-05
# Epoch 42/100
# 15/15 - 0s - 19ms/step - accuracy: 0.8915 - loss: 0.2891 - val_accuracy: 0.7083 - val_loss: 0.5788 - learning_rate: 5.0000e-05
# Epoch 43/100
# 15/15 - 0s - 19ms/step - accuracy: 0.8926 - loss: 0.2876 - val_accuracy: 0.7083 - val_loss: 0.5811 - learning_rate: 5.0000e-05
# Epoch 44/100
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 15/15 - 0s - 29ms/step - accuracy: 0.8926 - loss: 0.2863 - val_accuracy: 0.7135 - val_loss: 0.5786 - learning_rate: 5.0000e-05
# Epoch 45/100
# 15/15 - 1s - 39ms/step - accuracy: 0.8926 - loss: 0.2837 - val_accuracy: 0.6979 - val_loss: 0.5776 - learning_rate: 2.5000e-05
# Epoch 46/100
# 15/15 - 0s - 27ms/step - accuracy: 0.8926 - loss: 0.2830 - val_accuracy: 0.7031 - val_loss: 0.5719 - learning_rate: 2.5000e-05
# Epoch 47/100
# 15/15 - 1s - 49ms/step - accuracy: 0.8937 - loss: 0.2822 - val_accuracy: 0.7083 - val_loss: 0.5708 - learning_rate: 2.5000e-05
# Epoch 48/100
# 15/15 - 1s - 44ms/step - accuracy: 0.8958 - loss: 0.2816 - val_accuracy: 0.6927 - val_loss: 0.5675 - learning_rate: 2.5000e-05
# Epoch 49/100
# 15/15 - 1s - 48ms/step - accuracy: 0.8958 - loss: 0.2810 - val_accuracy: 0.6927 - val_loss: 0.5668 - learning_rate: 2.5000e-05
# Epoch 50/100
# 15/15 - 0s - 26ms/step - accuracy: 0.8958 - loss: 0.2804 - val_accuracy: 0.7083 - val_loss: 0.5656 - learning_rate: 2.5000e-05
# Epoch 51/100
# 15/15 - 0s - 24ms/step - accuracy: 0.8958 - loss: 0.2798 - val_accuracy: 0.6979 - val_loss: 0.5655 - learning_rate: 2.5000e-05
# Epoch 52/100
# 15/15 - 0s - 19ms/step - accuracy: 0.8947 - loss: 0.2792 - val_accuracy: 0.6979 - val_loss: 0.5655 - learning_rate: 2.5000e-05
# Epoch 53/100
# 15/15 - 0s - 20ms/step - accuracy: 0.8958 - loss: 0.2786 - val_accuracy: 0.6979 - val_loss: 0.5660 - learning_rate: 2.5000e-05
# Epoch 54/100
# 15/15 - 0s - 19ms/step - accuracy: 0.8958 - loss: 0.2780 - val_accuracy: 0.7031 - val_loss: 0.5668 - learning_rate: 2.5000e-05
# Epoch 55/100
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 15/15 - 0s - 19ms/step - accuracy: 0.8947 - loss: 0.2775 - val_accuracy: 0.7031 - val_loss: 0.5677 - learning_rate: 2.5000e-05
# Epoch 56/100
# 15/15 - 0s - 19ms/step - accuracy: 0.8958 - loss: 0.2763 - val_accuracy: 0.7031 - val_loss: 0.5684 - learning_rate: 1.2500e-05
# Epoch 57/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8947 - loss: 0.2761 - val_accuracy: 0.7031 - val_loss: 0.5680 - learning_rate: 1.2500e-05
# Epoch 58/100
# 15/15 - 0s - 20ms/step - accuracy: 0.8947 - loss: 0.2758 - val_accuracy: 0.7031 - val_loss: 0.5680 - learning_rate: 1.2500e-05
# Epoch 59/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8947 - loss: 0.2755 - val_accuracy: 0.7031 - val_loss: 0.5683 - learning_rate: 1.2500e-05
# Epoch 60/100
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 15/15 - 0s - 19ms/step - accuracy: 0.8937 - loss: 0.2752 - val_accuracy: 0.7031 - val_loss: 0.5684 - learning_rate: 1.2500e-05
# Epoch 61/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8947 - loss: 0.2747 - val_accuracy: 0.7083 - val_loss: 0.5682 - learning_rate: 6.2500e-06
# Epoch 62/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8947 - loss: 0.2746 - val_accuracy: 0.7083 - val_loss: 0.5680 - learning_rate: 6.2500e-06
# Epoch 63/100
# 15/15 - 0s - 18ms/step - accuracy: 0.8947 - loss: 0.2744 - val_accuracy: 0.7188 - val_loss: 0.5678 - learning_rate: 6.2500e-06
# Epoch 64/100
# 15/15 - 0s - 19ms/step - accuracy: 0.8947 - loss: 0.2743 - val_accuracy: 0.7135 - val_loss: 0.5678 - learning_rate: 6.2500e-06
# Epoch 65/100
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 15/15 - 0s - 18ms/step - accuracy: 0.8958 - loss: 0.2742 - val_accuracy: 0.7135 - val_loss: 0.5678 - learning_rate: 6.2500e-06
# Epoch 66/100
# 15/15 - 0s - 19ms/step - accuracy: 0.8980 - loss: 0.2739 - val_accuracy: 0.7188 - val_loss: 0.5675 - learning_rate: 3.1250e-06
# Epoch 66: early stopping
# Restoring model weights from the end of the best epoch: 51.
#
# Training time: 34.2s, epochs trained: 66

# %% [markdown]
# ## 7. Đánh giá trên test set

# %%
y_pred = model.predict(X_t, verbose=0).argmax(1)
f1m = f1_score(y_t, y_pred, average='macro')
report = classification_report(y_t, y_pred, target_names=['Normal','Shoplifting'], digits=4)
cm = confusion_matrix(y_t, y_pred)
print(f"\n=== V1.2 — 56 geometric features + split-by-clip ===")
print(report)
print(f"Confusion matrix:\n{cm}")
print(f"F1-macro: {f1m:.4f}")

# Save log
log = {
    "config": "v1.2_56feat_by_clip",
    "input_shape": [90, 56],
    "train_size": int(X_tr.shape[0]),
    "val_size": int(X_v.shape[0]),
    "test_size": int(X_t.shape[0]),
    "epochs_trained": len(hist.history['loss']),
    "best_val_loss": float(min(hist.history['val_loss'])),
    "test_f1_macro": float(f1m),
    "test_confusion_matrix": cm.tolist(),
    "test_classification_report": report,
    "train_time_sec": train_time,
    "history": {k: [float(v) for v in vs] for k, vs in hist.history.items()},
}
with open(f"{OUT_DIR}/log_v1.2_56feat_by_clip.json", "w") as f:
    json.dump(log, f, indent=2, ensure_ascii=False)
print(f"\n✓ Saved {OUT_DIR}/log_v1.2_56feat_by_clip.json")
# Out:
# === V1.2 — 56 geometric features + split-by-clip ===
#               precision    recall  f1-score   support
#
#       Normal     0.8144    0.6529    0.7248       121
#  Shoplifting     0.6379    0.8043    0.7115        92
#
#     accuracy                         0.7183       213
#    macro avg     0.7262    0.7286    0.7182       213
# weighted avg     0.7382    0.7183    0.7191       213
#
# Confusion matrix:
# [[79 42]
#  [18 74]]
# F1-macro: 0.7182
#
# ✓ Saved /content/drive/MyDrive/KLTN_KTDL_Nhom28/Human-Reco/training_outputs/log_v1.2_56feat_by_clip.json

# %% [markdown]
# ## 8. So sánh V1.1 (34 feat) vs V1.2 (56 feat)

# %%
# Load lại log V1.1 nếu có
v11_log = None
try:
    with open(f"{OUT_DIR}/log_v1.1_split_by_clip.json") as f:
        v11_log = json.load(f)
    print(f"V1.1 F1: {v11_log['test_f1_macro']:.4f}")
except FileNotFoundError:
    print("Không thấy V1.1 log — chỉ in V1.2")
print(f"V1.2 F1: {f1m:.4f}")
if v11_log:
    delta = f1m - v11_log['test_f1_macro']
    print(f"\nΔ V1.2 - V1.1: {delta:+.4f} (cùng split-by-clip, khác chỉ feature)")
    if delta > 0.05:
        print("→ 56 geometric features CÓ giúp ích. Tiếp tục cải tiến.")
    elif delta > 0:
        print("→ 56 feat có cải thiện nhẹ. Có thể cần combine với regularization/aug.")
    else:
        print("→ 56 feat KHÔNG giúp. Vấn đề ở kiến trúc/dataset. Cần chuyển ST-GCN V2.0.")
# Out:
# V1.1 F1: 0.5526
# V1.2 F1: 0.7182
#
# Δ V1.2 - V1.1: +0.1656 (cùng split-by-clip, khác chỉ feature)
# → 56 geometric features CÓ giúp ích. Tiếp tục cải tiến.

# %%
# Plot training curves
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(hist.history['accuracy'], label='train')
axes[0].plot(hist.history['val_accuracy'], label='val')
axes[0].set_title('V1.2 — Accuracy')
axes[0].set_xlabel('Epoch'); axes[0].legend(); axes[0].grid(alpha=0.3)
axes[1].plot(hist.history['loss'], label='train')
axes[1].plot(hist.history['val_loss'], label='val')
axes[1].set_title('V1.2 — Loss')
axes[1].set_xlabel('Epoch'); axes[1].legend(); axes[1].grid(alpha=0.3)
plt.tight_layout()
plt.savefig(f"{OUT_DIR}/v1.2_training_curves.png", dpi=150, bbox_inches='tight')
plt.show()

# CM
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal','Shoplifting'], yticklabels=['Normal','Shoplifting'])
plt.title(f'V1.2 — 56 feat + by-clip\nF1={f1m:.4f}')
plt.xlabel('Dự đoán'); plt.ylabel('Thực tế')
plt.tight_layout()
plt.savefig(f"{OUT_DIR}/v1.2_cm.png", dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 9. Quyết định bước tiếp theo
#
# | Kết quả V1.2 | Hành động |
# |---|---|
# | F1 ≥ 0,80 | Tuyệt vời — 56 feat đủ rồi. Tiếp tục V1.3 (regularize + augment) và V2.2 ensemble. |
# | F1 ≈ 0,65-0,79 | Hứa hẹn — tiếp tục V1.3 + V2.0 ST-GCN để bứt phá lên ngưỡng tối thiểu. |
# | F1 ≈ 0,55-0,65 | Yếu — vấn đề ở kiến trúc. Chuyển thẳng V2.0 ST-GCN. |
# | F1 < 0,55 | Có thể bug — verify lại data processing. |
#
# Gửi file `log_v1.2_56feat_by_clip.json` cho tôi để điền vào báo cáo Chương 3.5.1 (Bảng 3.2 mở rộng).
